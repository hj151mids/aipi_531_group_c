# %% [markdown]
# <a href="https://colab.research.google.com/github/hj151mids/aipi_531_group_c/blob/main/AIPI531_Project_SNQN_retailrocket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Mount you google drive with all the scripts and point to the folder containing the source code

# %%
# Mount Google Drive folder
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PROJ_DIR = '/content/drive/Othercomputers/My_MacBook_Pro/aipi_final_project/SA2C_code/Kaggle'
# change current directory after mounting
# %cd $PROJ_DIR
! ls
# Out:
# /content/drive/Othercomputers/My_MacBook_Pro/aipi_final_project/SA2C_code/Kaggle
# data		     preprocess_kaggle.py  SA2C.py	     SNQN_v1.py
# DQN_NS.py	     __pycache__	   SA2C_upgrade.py   split_data.py
# NextItNetModules.py  replay_buffer.py	   SASRecModules.py  test.py
# pop.py		     report_SA2C.txt	   SNQN.py	     utility.py

# %% [markdown]
# ## 2) Upgrade the source code to TF2 using the following command

# %%
# !tf_upgrade_v2 \
  --infile '/content/drive/Othercomputers/My_MacBook_Pro/aipi_final_project/SA2C_code/Kaggle/SNQN.py' \
  --outfile '/content/drive/Othercomputers/My_MacBook_Pro/aipi_final_project/SA2C_code/Kaggle/SNQN_v1.py' \
  --reportfile report_SNQN.txt

# %% [markdown]
# You might encounter this error `AttributeError: module 'tensorflow' has no attribute 'contrib'`
# To resolve this, replace the fully connected layer in your source code to dense layer (You have to do this in every file that you work with)
# ![tf1.png](data:image/png;base64,...)
#
# ![tf2.png](data:image/png;base64,...)

# %% [markdown]
# You might also encounter `RuntimeError: tf.placeholder() is not compatible with eager execution.`
# To resolve this, disable eager execution at the beginning(You can place this on the first line of the init funtion)
# `tf.compat.v1.disable_eager_execution()`
#
# After you make the changes, reupload the file to the drive and execute the `tf_upgrade_v2` command with the newly modified file

# %%
! pip install pandas trfl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 kB 3.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# > Run SNQN model with retailrocket dataset without item feamtures

# %%
! python SNQN_v1.py --model=GRU --epoch=1
# Out:
# 2023-04-26 13:16:26.188472: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-26 13:16:27.561041: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/Othercomputers/My_MacBook_Pro/aipi_final_project/SA2C_code/Kaggle/SNQN_v1.py:118: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   tf.compat.v1.nn.rnn_cell.GRUCell(self.hidden_size),
# ...
